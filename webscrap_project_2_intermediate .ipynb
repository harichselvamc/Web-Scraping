# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
website='https://www.cars.com/shopping/results/?dealer_id=&keyword=&list_price_max=&list_price_min=&makes[]=mercedes_benz&maximum_distance=all&mileage_max=&monthly_payment=&page_size=20&sort=best_match_desc&stock_type=cpo&year_max=&year_min=&zip='

# %%
response=requests.get(website)

# %%
response
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(response.content,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="ep-theme-spark" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title data-suffix=" | Cars.com">Certified Used Mercedes-Benz for Sale Nationwide | Cars.com</title>
# <meta content="Shop Mercedes-Benz vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 10,000+ Mercedes-Benz models nationwide." name="description"/>
# <meta content="noindex, nofollow" name="robots">
# <meta content="Cars.com" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="Certified Used Mercedes-Benz for Sale Nationwide | Cars.com" property="og:title"/>
# <meta content="https://www.cars.com/shopping/results/" property="og:url"/>
# ...

# %%
results=soup.find_all("div",{'class':'vehicle-card'})

# %%
len(results)
# Out:
# 20

# %%
results[0]
# Out:
# <div class="vehicle-card inventory-ad" data-inventory-ad="true" data-koddi-click-tracking-url="https://cars.koddi.io/event-collection/beacon?action=click&amp;trackingData={trackingData}&amp;rank={rank}&amp;clientName=Cars&amp;beaconIssued=2023-07-13T19:15:03Z" data-koddi-impression-tracking-url="https://cars.koddi.io/event-collection/beacon?action=impression&amp;trackingData={trackingData}&amp;rank={rank}&amp;ts={ts}&amp;clientName=Cars&amp;beaconIssued=2023-07-13T19:15:03Z" data-koddi-listing-id="3e753f65-285c-4e97-855e-bfdaca0bf5b4" data-koddi-tracking-data="..." data-koddi-tracking-guid="7abc0114-2a56-47f9-8d9d-932d3c8615f9" data-listing-id="3e753f65-285c-4e97-855e-bfdaca0bf5b4" data-tracking-id="1" data-tracking-type="srp-vehicle-card" id="vehicle-card-3e753f65-285c-4e97-855e-bfdaca0bf5b4-sponsored" phx-hook="VehicleCard" phx-target="8" trid="tttOdXltwtEN50MEaulX9W" trsi="" trv="">
# ...

# %%
results[0].find('h2').get_text()
# Out:
# '2022 Mercedes-Benz GLB 250 Base'

# %%
results[0].find('div',{'class':'mileage'}).get_text()
# Out:
# '9,400 mi.'

# %%
results[0].find('span',{'class':'sds-rating__count'}).get_text()
# Out:
# '4.9'

# %%
results[0].find('span',{'class':'sds-rating__link'}).get_text()
# Out:
# '(1,988 reviews)'

# %%
results[0].find('span',{"class":"primary-price"}).get_text()
# Out:
# '$45,993'

# %%
results[0].find('div',{'class':'dealer-name'}).get_text().strip()
# Out:
# 'Mercedes-Benz of San Antonio'

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for result in results:
    
    # name
    try:
        name.append(result.find('h2').get_text()) 
    except:
        name.append('n/a')
    
    # mileage
    try:
        mileage.append(result.find('div', {'class':'mileage'}).get_text())
    except:
        mileage.append('n/a')
    
    # dealer_name
    try:
        dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
    except:
        dealer_name.append('n/a')
        
    # rating
    try:
        rating.append(result.find('span', {'class':'sds-rating__count'}).get_text())
    except:
        rating.append('n/a')
    
    # review_count
    try:
        review_count.append(result.find('span', {'class':'sds-rating__link'}).get_text())
    except:
        review_count.append('n/a')
    
    #price 
    try:
        price.append(result.find('span', {'class':'primary-price'}).get_text())
    except:
        price.append('n/a')

# %%
name
# Out:
# ['2022 Mercedes-Benz GLB 250 Base',
#  '2019 Mercedes-Benz S-Class S 560 4MATIC',
#  '2019 Mercedes-Benz AMG E 53 Base 4MATIC',
#  '2022 Mercedes-Benz CLS 450 Base 4MATIC',
#  '2021 Mercedes-Benz GLS 580 Base 4MATIC',
#  '2022 Mercedes-Benz E-Class E 350 4MATIC',
#  '2020 Mercedes-Benz AMG CLA 35 Base 4MATIC',
#  '2021 Mercedes-Benz GLE 450 AWD 4MATIC',
#  '2023 Mercedes-Benz GLE 350 Base 4MATIC',
#  '2021 Mercedes-Benz AMG C 43 Base 4MATIC',
#  '2021 Mercedes-Benz AMG GLE 53 Base',
#  '2019 Mercedes-Benz AMG C 63 S',
#  '2021 Mercedes-Benz AMG GLE 53 Base',
#  '2023 Mercedes-Benz AMG GT 43 Base',
#  '2022 Mercedes-Benz EQS 450+ Base',
#  '2022 Mercedes-Benz AMG GLA 35 Base',
#  '2019 Mercedes-Benz E-Class E 300',
#  '2022 Mercedes-Benz S-Class S 580 4MATIC',
#  '2020 Mercedes-Benz S-Class S 450 4MATIC',
#  '2022 Mercedes-Benz AMG C 43 Base 4MATIC']

# %%
mileage
# Out:
# ['9,400 mi.',
#  '12,417 mi.',
#  '23,163 mi.',
#  '11,611 mi.',
#  '26,620 mi.',
#  '5,736 mi.',
#  '25,929 mi.',
#  '16,210 mi.',
#  '1,448 mi.',
#  '10,013 mi.',
#  '23,988 mi.',
#  '18,149 mi.',
#  '15,315 mi.',
#  '1,973 mi.',
#  '7,000 mi.',
#  '17,496 mi.',
#  '20,336 mi.',
#  '12,429 mi.',
#  '30,972 mi.',
#  '10,381 mi.']

# %%
dealer_name
# Out:
# ['Mercedes-Benz of San Antonio',
#  'Benzel-Busch Motor Car',
#  'Mercedes-Benz of State College',
#  'Benzel-Busch Motor Car',
#  'Mercedes-Benz of Houston Greenway',
#  'Euro Motorcars Devon',
#  'Mercedes-Benz of Tysons Corner',
#  'Volkswagen of Quad Cities',
#  'Benzel-Busch Motor Car',
#  'Mercedes-Benz of West Houston',
#  'Mercedes-Benz of State College',
#  'Mercedes-Benz of West Houston',
#  'Mercedes-Benz of Marin',
#  'Mercedes-Benz Of Tampa',
#  'House of Imports',
#  'Mercedes-Benz of Milwaukee North',
#  'Benzel-Busch Motor Car',
#  'Mercedes-Benz of Hoffman Estates',
#  'Mercedes-Benz of Nanuet',
#  'Mercedes-Benz of Hoffman Estates']

# %%
rating
# Out:
# ['4.9',
#  '4.5',
#  'n/a',
#  '4.5',
#  '4.8',
#  '4.1',
#  '4.6',
#  '4.8',
#  '4.5',
#  '4.7',
#  'n/a',
#  '4.7',
#  'n/a',
#  '4.1',
#  '4.7',
#  'n/a',
#  '4.5',
#  '4.6',
#  '4.7',
#  '4.6']

# %%
price
# Out:
# ['$45,993',
#  '$79,998',
#  '$62,401',
#  '$67,924',
#  '$83,562',
#  '$59,825',
#  '$38,995',
#  '$62,800',
#  '$65,913',
#  '$48,496',
#  '$75,991',
#  '$63,995',
#  '$72,555',
#  '$98,961',
#  '$71,498',
#  '$45,620',
#  '$39,435',
#  '$109,999',
#  '$57,998',
#  '$72,999']

# %%
# dictionary
car_dealer = pd.DataFrame({'Name': name, 'Mileage':mileage, 'Dealer Name':dealer_name,'Rating': rating, 'Review Count': review_count, 'Price': price})

# %%
car_dealer
# Out:
#                                          Name     Mileage  \
# 0             2022 Mercedes-Benz GLB 250 Base   9,400 mi.
# 1     2019 Mercedes-Benz S-Class S 560 4MATIC  12,417 mi.
# 2     2019 Mercedes-Benz AMG E 53 Base 4MATIC  23,163 mi.
# 3      2022 Mercedes-Benz CLS 450 Base 4MATIC  11,611 mi.
# 4      2021 Mercedes-Benz GLS 580 Base 4MATIC  26,620 mi.
# 5     2022 Mercedes-Benz E-Class E 350 4MATIC   5,736 mi.
# 6   2020 Mercedes-Benz AMG CLA 35 Base 4MATIC  25,929 mi.
# 7       2021 Mercedes-Benz GLE 450 AWD 4MATIC  16,210 mi.
# 8      2023 Mercedes-Benz GLE 350 Base 4MATIC   1,448 mi.
# 9     2021 Mercedes-Benz AMG C 43 Base 4MATIC  10,013 mi.
# 10         2021 Mercedes-Benz AMG GLE 53 Base  23,988 mi.
# 11              2019 Mercedes-Benz AMG C 63 S  18,149 mi.
# 12         2021 Mercedes-Benz AMG GLE 53 Base  15,315 mi.
# 13          2023 Mercedes-Benz AMG GT 43 Base   1,973 mi.
# 14           2022 Mercedes-Benz EQS 450+ Base   7,000 mi.
# ...

# %%
car_dealer['Review Count'] = car_dealer['Review Count'].apply(lambda x: x.strip('reviews)').strip('('))

# %%
car_dealer
# Out:
#                                          Name     Mileage  \
# 0             2022 Mercedes-Benz GLB 250 Base   9,400 mi.
# 1     2019 Mercedes-Benz S-Class S 560 4MATIC  12,417 mi.
# 2     2019 Mercedes-Benz AMG E 53 Base 4MATIC  23,163 mi.
# 3      2022 Mercedes-Benz CLS 450 Base 4MATIC  11,611 mi.
# 4      2021 Mercedes-Benz GLS 580 Base 4MATIC  26,620 mi.
# 5     2022 Mercedes-Benz E-Class E 350 4MATIC   5,736 mi.
# 6   2020 Mercedes-Benz AMG CLA 35 Base 4MATIC  25,929 mi.
# 7       2021 Mercedes-Benz GLE 450 AWD 4MATIC  16,210 mi.
# 8      2023 Mercedes-Benz GLE 350 Base 4MATIC   1,448 mi.
# 9     2021 Mercedes-Benz AMG C 43 Base 4MATIC  10,013 mi.
# 10         2021 Mercedes-Benz AMG GLE 53 Base  23,988 mi.
# 11              2019 Mercedes-Benz AMG C 63 S  18,149 mi.
# 12         2021 Mercedes-Benz AMG GLE 53 Base  15,315 mi.
# 13          2023 Mercedes-Benz AMG GT 43 Base   1,973 mi.
# 14           2022 Mercedes-Benz EQS 450+ Base   7,000 mi.
# ...

# %%
car_dealer.to_excel('car_dealer_single_page.xlsx', index=False)

# %% [markdown]
# multiple page

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for i in range (1,11):
    
    # website in variable
    website = 'https://www.cars.com/shopping/results/?page='+ str(i) +'&page_size=20&dealer_id=&list_price_max=&list_price_min=&makes[]=mercedes_benz&maximum_distance=20&mileage_max=&sort=best_match_desc&stock_type=cpo&year_max=&year_min=&zip=' 
    
    # request to website
    response = requests.get(website)
    
    # soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # results
    results = soup.find_all('div', {'class' : 'vehicle-card'})
    
    # loop through results
    for result in results:
    
        # name
        try:
            name.append(result.find('h2').get_text()) 
        except:
            name.append('n/a')

        # mileage
        try:
            mileage.append(result.find('div', {'class':'mileage'}).get_text())
        except:
            mileage.append('n/a')

        # dealer_name
        try:
            dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
        except:
            dealer_name.append('n/a')

        # rating
        try:
            rating.append(result.find('span', {'class':'sds-rating__count'}).get_text())
        except:
            rating.append('n/a')

        # review_count
        try:
            review_count.append(result.find('span', {'class':'sds-rating__link'}).get_text())
        except:
            review_count.append('n/a')

        #price 
        try:
            price.append(result.find('span', {'class':'primary-price'}).get_text())
        except:
            price.append('n/a')

# %%
# dictionary
car_dealer = pd.DataFrame({'Name': name, 'Mileage':mileage, 'Dealer Name':dealer_name,'Rating': rating, 'Review Count': review_count, 'Price': price})

# %%
car_dealer
# Out:
#                                         Name     Mileage  \
# 0            2022 Mercedes-Benz GLB 250 Base   9,400 mi.
# 1    2019 Mercedes-Benz S-Class S 560 4MATIC  12,417 mi.
# 2    2019 Mercedes-Benz AMG E 53 Base 4MATIC  23,163 mi.
# 3     2021 Mercedes-Benz GLS 580 Base 4MATIC  26,620 mi.
# 4     2022 Mercedes-Benz CLS 450 Base 4MATIC  11,611 mi.
# ..                                       ...         ...
# 201   2019 Mercedes-Benz GLS 450 Base 4MATIC  26,992 mi.
# 202     2019 Mercedes-Benz AMG E 63 S 4MATIC  35,653 mi.
# 203       2021 Mercedes-Benz AMG GLE 53 Base  23,005 mi.
# 204        2022 Mercedes-Benz AMG GT 53 Base   5,091 mi.
# 205  2022 Mercedes-Benz Maybach S 580 4MATIC   5,211 mi.
#
#                            Dealer Name Rating     Review Count     Price
# 0         Mercedes-Benz of San Antonio    4.9  (1,988 reviews)   $45,993
# 1               Benzel-Busch Motor Car    4.5  (5,335 reviews)   $79,998
# ...
